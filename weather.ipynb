# %%
import requests
import datetime as dt 

BASE_URL = 'http://api.openweathermap.org/data/2.5/forecast?'
API_KEY = str(open('api_key.txt', 'r').read())
CITY = 'Frankfurt'
url = BASE_URL + "appid=" + API_KEY + "&q=" + CITY + ',de'

response = requests.get(url).json()
print(len(response))
print(response)
# Out:
# 5
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1677952800, 'main': {'temp': 279.04, 'feels_like': 277.01, 'temp_min': 277.98, 'temp_max': 279.04, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1008, 'humidity': 71, 'temp_kf': 1.06}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 2.62, 'deg': 300, 'gust': 6.3}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-04 18:00:00'}, {'dt': 1677963600, 'main': {'temp': 278.09, 'feels_like': 276.28, 'temp_min': 277.35, 'temp_max': 278.09, 'pressure': 1022, 'sea_level': 1022, 'grnd_level': 1008, 'humidity': 77, 'temp_kf': 0.74}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 2.17, 'deg': 301, 'gust': 5.07}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-04 21:00:00'}, {'dt': 1677974400, 'main': {'temp': 277.17, 'feels_like': 275.77, 'temp_min': 277.17, 'temp_max': 277.17, 'pressure': 1021, 'sea_level': 1021, 'grnd_level': 1007, 'humidity': 79, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.66, 'deg': 311, 'gust': 4.62}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-05 00:00:00'}, {'dt': 1677985200, 'main': {'temp': 276.69, 'feels_like': 274.76, 'temp_min': 276.69, 'temp_max': 276.69, 'pressure': 1020, 'sea_level': 1020, 'grnd_level': 1006, 'humidity': 76, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 2.05, 'deg': 307, 'gust': 5.07}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-05 03:00:00'}, {'dt': 1677996000, 'main': {'temp': 275.9, 'feels_like': 273.16, 'temp_min': 275.9, 'temp_max': 275.9, 'pressure': 1019, 'sea_level': 1019, 'grnd_level': 1005, 'humidity': 78, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 2.75, 'deg': 289, 'gust': 6.4}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-05 06:00:00'}, {'dt': 1678006800, 'main': {'temp': 277.46, 'feels_like': 274.31, 'temp_min': 277.46, 'temp_max': 277.46, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 1005, 'humidity': 64, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 99}, 'wind': {'speed': 3.76, 'deg': 292, 'gust': 5.55}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-03-05 09:00:00'}, {'dt': 1678017600, 'main': {'temp': 279.01, 'feels_like': 276.15, 'temp_min': 279.01, 'temp_max': 279.01, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 1003, 'humidity': 51, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 99}, 'wind': {'speed': 3.85, 'deg': 297, 'gust': 5.13}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-03-05 12:00:00'}, {'dt': 1678028400, 'main': {'temp': 279.3, 'feels_like': 276.57, 'temp_min': 279.3, 'temp_max': 279.3, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 1001, 'humidity': 51, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 3.74, 'deg': 297, 'gust': 5.52}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-03-05 15:00:00'}, {'dt': 1678039200, 'main': {'temp': 277.55, 'feels_like': 275.31, 'temp_min': 277.55, 'temp_max': 277.55, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 1001, 'humidity': 63, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 2.53, 'deg': 294, 'gust': 5.6}, 'visibilit ...

# %%
def get_weather_data(response):
    """ Die Funktion wird dazu verwendet , die verschiedene Wetter-Datenpunkte 
    einer gegebenen Stadt auszulesen 
        
    Args:
        data (dict): Dictionnary of weather params for the last 5 days 
    """
    # in list is weather , wind , dt_txt ,main
    #in main(dict) is temp_max , temp_min , feels_like , temp , pressure and humidity
    #in Wind(dict) is speed
    # in weather (list(dict)) is main , description and Icon 
    print(f'weather Prevision for {CITY} :')
    data_dict = response['list']
    if type(data_dict) is list :
        for i in data_dict :
            dt_txt = i['dt_txt']
            temp_min = round(float(i['main']['temp_min']) - 272.15 , 3)
            temp_max = round(float (i['main']['temp_max']) - 272.15 , 3)
            feels_like = round(float(i['main']['feels_like']) - 272.15 ,3 )
            pressure = float(i['main']['pressure']) #--> bar
            humidity = i['main']['humidity'] #--> prozentangabe
            wind = i['wind']['speed'] #--> m/s
            if type(i['weather']) is list and len(i['weather']) >=1 :
                description_set = dict()
                j = 0
                for k in i['weather']:
                    j = j + 1 
                    main_description = k['main']
                    description = k['description']
                    tuple_description = (main_description , description)
                    description_set[j] = tuple_description
        #print Ausgabe 
            print('--------------------------------------------------')
            print(dt_txt)
            print('###################################################')
            keys = list(description_set.keys())
            for key in keys :
                print(f'main description: {description_set[key][0]}')
                print(f'main description: {description_set[key][1]}')
            print(f'minimale Temperatur: {temp_min} °C')
            print(f'maximale Temperatur: {temp_max} °C')
            print(f'feels_like/gefühlt: {feels_like} °C')
            print(f'Pressure / Druck: {pressure} bar')
            print(f'humidity / Luftfeuchtigkeit: {humidity} %')
            print(f'wind speed / Luftgeschwindigkeit: {wind} m/s')
get_weather_data(dict(response))
# Out:
# weather Prevision for Frankfurt :
# --------------------------------------------------
# 2023-03-04 18:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 5.83 °C
# maximale Temperatur: 6.89 °C
# feels_like/gefühlt: 4.86 °C
# Pressure / Druck: 1021.0 bar
# humidity / Luftfeuchtigkeit: 71 %
# wind speed / Luftgeschwindigkeit: 2.62 m/s
# --------------------------------------------------
# 2023-03-04 21:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 5.2 °C
# maximale Temperatur: 5.94 °C
# feels_like/gefühlt: 4.13 °C
# Pressure / Druck: 1022.0 bar
# humidity / Luftfeuchtigkeit: 77 %
# wind speed / Luftgeschwindigkeit: 2.17 m/s
# --------------------------------------------------
# 2023-03-05 00:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 5.02 °C
# maximale Temperatur: 5.02 °C
# feels_like/gefühlt: 3.62 °C
# Pressure / Druck: 1021.0 bar
# humidity / Luftfeuchtigkeit: 79 %
# wind speed / Luftgeschwindigkeit: 1.66 m/s
# --------------------------------------------------
# 2023-03-05 03:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 4.54 °C
# maximale Temperatur: 4.54 °C
# feels_like/gefühlt: 2.61 °C
# Pressure / Druck: 1020.0 bar
# humidity / Luftfeuchtigkeit: 76 %
# wind speed / Luftgeschwindigkeit: 2.05 m/s
# --------------------------------------------------
# 2023-03-05 06:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 3.75 °C
# maximale Temperatur: 3.75 °C
# feels_like/gefühlt: 1.01 °C
# Pressure / Druck: 1019.0 bar
# humidity / Luftfeuchtigkeit: 78 %
# wind speed / Luftgeschwindigkeit: 2.75 m/s
# --------------------------------------------------
# 2023-03-05 09:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 5.31 °C
# maximale Temperatur: 5.31 °C
# feels_like/gefühlt: 2.16 °C
# Pressure / Druck: 1018.0 bar
# humidity / Luftfeuchtigkeit: 64 %
# wind speed / Luftgeschwindigkeit: 3.76 m/s
# --------------------------------------------------
# 2023-03-05 12:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 6.86 °C
# maximale Temperatur: 6.86 °C
# feels_like/gefühlt: 4.0 °C
# Pressure / Druck: 1017.0 bar
# humidity / Luftfeuchtigkeit: 51 %
# wind speed / Luftgeschwindigkeit: 3.85 m/s
# --------------------------------------------------
# 2023-03-05 15:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 7.15 °C
# maximale Temperatur: 7.15 °C
# feels_like/gefühlt: 4.42 °C
# Pressure / Druck: 1015.0 bar
# humidity / Luftfeuchtigkeit: 51 %
# wind speed / Luftgeschwindigkeit: 3.74 m/s
# --------------------------------------------------
# 2023-03-05 18:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 5.4 °C
# maximale Temperatur: 5.4 °C
# feels_like/gefühlt: 3.16 °C
# Pressure / Druck: 1014.0 bar
# humidity / Luftfeuchtigkeit: 63 %
# wind speed / Luftgeschwindigkeit: 2.53 m/s
# --------------------------------------------------
# 2023-03-05 21:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 4.42 °C
# maximale Temperatur: 4.42 °C
# feels_like/gefühlt: 2.66 °C
# Pressure / Druck: 1014.0 bar
# humidity / Luftfeuchtigkeit: 70 %
# wind speed / Luftgeschwindigkeit: 1.88 m/s
# --------------------------------------------------
# 2023-03-06 00:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 3.47 °C
# maximale Temperatur: 3.47 °C
# feels_like/gefühlt: 3.47 °C
# Pressure / Druck: 1013.0 bar
# humidity / Luftfeuchtigkeit: 74 %
# wind speed / Luftgeschwindigkeit: 0.94 m/s
# --------------------------------------------------
# 2023-03-06 03:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 2.61 °C
# maximale Temperatur: 2.61 °C
# feels_like/gefühlt: 2.61 °C
# Pressure / Druck: 1012.0 bar
# humidity / Luftfeuchtigkeit: 78 %
# wind speed / Luftgeschwindigkeit: 0.52 m/s
# --------------------------------------------------
# 2023-03-06 06:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 2.34 °C
# maximale Temperatur: 2.34 °C
# feels_like/gefühlt: 2.34 °C
# Pressure / Druck: 1011.0 bar
# humidity / Luftfeuchtigkeit: 80 %
# wind speed / Luftgeschwindigkeit: 0.89 m/s
# --------------------------------------------------
# 2023-03-06 09:00:00
# ###################################################
# main description: Clouds
# main description: broken clouds
# minimale Temperatur: 5.19 °C
# maximale Temperatur: 5.19 °C
# feels_like/gefühlt: 3.1 °C
# Pressure / Druck: 1011.0 bar
# humidity / Luftfeuchtigkeit: 64 %
# wind speed / Luftgeschwindigkeit: 2.32 m/s
# --------------------------------------------------
# 2023-03-06 12:00:00
# ###################################################
# main description: Rain
# main description: light rain
# minimale Temperatur: 6.91 °C
# maximale Temperatur: 6.91 °C
# feels_like/gefühlt: 4.11 °C
# Pressure / Druck: 1009.0 bar
# humidity / Luftfeuchtigkeit: 57 %
# wind speed / Luftgeschwindigkeit: 3.76 m/s
# --------------------------------------------------
# 2023-03-06 15:00:00
# ###################################################
# main description: Rain
# main description: light rain
# minimale Temperatur: 7.28 °C
# maximale Temperatur: 7.28 °C
# feels_like/gefühlt: 4.18 °C
# Pressure / Druck: 1007.0 bar
# humidity / Luftfeuchtigkeit: 58 %
# wind speed / Luftgeschwindigkeit: 4.48 m/s
# --------------------------------------------------
# 2023-03-06 18:00:00
# ###################################################
# main description: Snow
# main description: light snow
# minimale Temperatur: 5.65 °C
# maximale Temperatur: 5.65 °C
# feels_like/gefühlt: 2.11 °C
# Pressure / Druck: 1006.0 bar
# humidity / Luftfeuchtigkeit: 62 %
# wind speed / Luftgeschwindigkeit: 4.57 m/s
# --------------------------------------------------
# 2023-03-06 21:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 4.75 °C
# maximale Temperatur: 4.75 °C
# feels_like/gefühlt: 0.85 °C
# Pressure / Druck: 1006.0 bar
# humidity / Luftfeuchtigkeit: 70 %
# wind speed / Luftgeschwindigkeit: 4.84 m/s
# --------------------------------------------------
# 2023-03-07 00:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 4.45 °C
# maximale Temperatur: 4.45 °C
# feels_like/gefühlt: 0.28 °C
# Pressure / Druck: 1005.0 bar
# humidity / Luftfeuchtigkeit: 72 %
# wind speed / Luftgeschwindigkeit: 5.23 m/s
# --------------------------------------------------
# 2023-03-07 03:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 3.69 °C
# maximale Temperatur: 3.69 °C
# feels_like/gefühlt: -0.93 °C
# Pressure / Druck: 1003.0 bar
# humidity / Luftfeuchtigkeit: 74 %
# wind speed / Luftgeschwindigkeit: 5.76 m/s
# --------------------------------------------------
# 2023-03-07 06:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 3.21 °C
# maximale Temperatur: 3.21 °C
# feels_like/gefühlt: -1.41 °C
# Pressure / Druck: 1002.0 bar
# humidity / Luftfeuchtigkeit: 79 %
# wind speed / Luftgeschwindigkeit: 5.51 m/s
# --------------------------------------------------
# 2023-03-07 09:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 5.08 °C
# maximale Temperatur: 5.08 °C
# feels_like/gefühlt: 0.85 °C
# Pressure / Druck: 1002.0 bar
# humidity / Luftfeuchtigkeit: 68 %
# wind speed / Luftgeschwindigkeit: 5.71 m/s
# --------------------------------------------------
# 2023-03-07 12:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 7.88 °C
# maximale Temperatur: 7.88 °C
# feels_like/gefühlt: 4.25 °C
# Pressure / Druck: 1000.0 bar
# humidity / Luftfeuchtigkeit: 54 %
# wind speed / Luftgeschwindigkeit: 6.08 m/s
# --------------------------------------------------
# 2023-03-07 15:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 8.6 °C
# maximale Temperatur: 8.6 °C
# feels_like/gefühlt: 5.47 °C
# Pressure / Druck: 998.0 bar
# humidity / Luftfeuchtigkeit: 50 %
# wind speed / Luftgeschwindigkeit: 5.28 m/s
# --------------------------------------------------
# 2023-03-07 18:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 6.72 °C
# maximale Temperatur: 6.72 °C
# feels_like/gefühlt: 3.54 °C
# Pressure / Druck: 999.0 bar
# humidity / Luftfeuchtigkeit: 58 %
# wind speed / Luftgeschwindigkeit: 4.37 m/s
# --------------------------------------------------
# 2023-03-07 21:00:00
# ###################################################
# main description: Rain
# main description: light rain
# minimale Temperatur: 5.32 °C
# maximale Temperatur: 5.32 °C
# feels_like/gefühlt: 2.23 °C
# Pressure / Druck: 997.0 bar
# humidity / Luftfeuchtigkeit: 73 %
# wind speed / Luftgeschwindigkeit: 3.66 m/s
# --------------------------------------------------
# 2023-03-08 00:00:00
# ###################################################
# main description: Snow
# main description: snow
# minimale Temperatur: 3.42 °C
# maximale Temperatur: 3.42 °C
# feels_like/gefühlt: 0.8 °C
# Pressure / Druck: 996.0 bar
# humidity / Luftfeuchtigkeit: 97 %
# wind speed / Luftgeschwindigkeit: 2.55 m/s
# --------------------------------------------------
# 2023-03-08 03:00:00
# ###################################################
# main description: Snow
# main description: light snow
# minimale Temperatur: 2.61 °C
# maximale Temperatur: 2.61 °C
# feels_like/gefühlt: -0.49 °C
# Pressure / Druck: 997.0 bar
# humidity / Luftfeuchtigkeit: 92 %
# wind speed / Luftgeschwindigkeit: 2.91 m/s
# --------------------------------------------------
# 2023-03-08 06:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 1.53 °C
# maximale Temperatur: 1.53 °C
# feels_like/gefühlt: 1.53 °C
# Pressure / Druck: 998.0 bar
# humidity / Luftfeuchtigkeit: 83 %
# wind speed / Luftgeschwindigkeit: 1.26 m/s
# --------------------------------------------------
# 2023-03-08 09:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 2.41 °C
# maximale Temperatur: 2.41 °C
# feels_like/gefühlt: 0.5 °C
# Pressure / Druck: 998.0 bar
# humidity / Luftfeuchtigkeit: 75 %
# wind speed / Luftgeschwindigkeit: 1.75 m/s
# --------------------------------------------------
# 2023-03-08 12:00:00
# ###################################################
# main description: Snow
# main description: light snow
# minimale Temperatur: 2.13 °C
# maximale Temperatur: 2.13 °C
# feels_like/gefühlt: -0.6 °C
# Pressure / Druck: 998.0 bar
# humidity / Luftfeuchtigkeit: 88 %
# wind speed / Luftgeschwindigkeit: 2.42 m/s
# --------------------------------------------------
# 2023-03-08 15:00:00
# ###################################################
# main description: Snow
# main description: light snow
# minimale Temperatur: 3.05 °C
# maximale Temperatur: 3.05 °C
# feels_like/gefühlt: 0.83 °C
# Pressure / Druck: 1000.0 bar
# humidity / Luftfeuchtigkeit: 78 %
# wind speed / Luftgeschwindigkeit: 2.09 m/s
# --------------------------------------------------
# 2023-03-08 18:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 2.44 °C
# maximale Temperatur: 2.44 °C
# feels_like/gefühlt: 2.44 °C
# Pressure / Druck: 1002.0 bar
# humidity / Luftfeuchtigkeit: 81 %
# wind speed / Luftgeschwindigkeit: 0.34 m/s
# --------------------------------------------------
# 2023-03-08 21:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 1.98 °C
# maximale Temperatur: 1.98 °C
# feels_like/gefühlt: 0.36 °C
# Pressure / Druck: 1004.0 bar
# humidity / Luftfeuchtigkeit: 87 %
# wind speed / Luftgeschwindigkeit: 1.5 m/s
# --------------------------------------------------
# 2023-03-09 00:00:00
# ###################################################
# main description: Clouds
# main description: overcast clouds
# minimale Temperatur: 1.75 °C
# maximale Temperatur: 1.75 °C
# feels_like/gefühlt: 1.75 °C
# Pressure / Druck: 1003.0 bar
# humidity / Luftfeuchtigkeit: 89 %
# wind speed / Luftgeschwindigkeit: 1.13 m/s
# --------------------------------------------------
# 2023-03-09 03:00:00
# ###################################################
# main description: Snow
# main description: light snow
# minimale Temperatur: 1.42 °C
# maximale Temperatur: 1.42 °C
# feels_like/gefühlt: -0.05 °C
# Pressure / Druck: 1002.0 bar
# humidity / Luftfeuchtigkeit: 99 %
# wind speed / Luftgeschwindigkeit: 1.36 m/s
# --------------------------------------------------
# 2023-03-09 06:00:00
# ###################################################
# main description: Snow
# main description: snow
# minimale Temperatur: 1.35 °C
# maximale Temperatur: 1.35 °C
# feels_like/gefühlt: -0.23 °C
# Pressure / Druck: 1000.0 bar
# humidity / Luftfeuchtigkeit: 100 %
# wind speed / Luftgeschwindigkeit: 1.42 m/s
# --------------------------------------------------
# 2023-03-09 09:00:00
# ###################################################
# main description: Rain
# main description: light rain
# minimale Temperatur: 1.93 °C
# maximale Temperatur: 1.93 °C
# feels_like/gefühlt: 1.93 °C
# Pressure / Druck: 1000.0 bar
# humidity / Luftfeuchtigkeit: 100 %
# wind speed / Luftgeschwindigkeit: 0.68 m/s
# --------------------------------------------------
# 2023-03-09 12:00:00
# ###################################################
# main description: Rain
# main description: light rain
# minimale Temperatur: 2.45 °C
# maximale Temperatur: 2.45 °C
# feels_like/gefühlt: 2.45 °C
# Pressure / Druck: 1000.0 bar
# humidity / Luftfeuchtigkeit: 99 %
# wind speed / Luftgeschwindigkeit: 0.57 m/s
# --------------------------------------------------
# 2023-03-09 15:00:00
# ###################################################
# main description: Rain
# main description: light rain
# minimale Temperatur: 2.74 °C
# maximale Temperatur: 2.74 °C
# feels_like/gefühlt: 2.74 °C
# Pressure / Druck: 1000.0 bar
# humidity / Luftfeuchtigkeit: 100 %
# wind speed / Luftgeschwindigkeit: 1.23 m/s

# %%
import requests
import datetime as dt 

BASE_URL = 'http://api.openweathermap.org/data/2.5/forecast?'
API_KEY = str(open('api_key.txt', 'r').read())
CITY = 'New York'
url = BASE_URL + "appid=" + API_KEY + "&q=" + CITY

response = requests.get(url).json()
print(len(response))
print(response)
# Out:
# 5
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1677801600, 'main': {'temp': 283.12, 'feels_like': 279.92, 'temp_min': 279.57, 'temp_max': 283.12, 'pressure': 1007, 'sea_level': 1007, 'grnd_level': 1009, 'humidity': 55, 'temp_kf': 3.55}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 33}, 'wind': {'speed': 7.48, 'deg': 326, 'gust': 15.06}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-03 00:00:00'}, {'dt': 1677812400, 'main': {'temp': 279.94, 'feels_like': 275.92, 'temp_min': 277.46, 'temp_max': 279.94, 'pressure': 1010, 'sea_level': 1010, 'grnd_level': 1011, 'humidity': 59, 'temp_kf': 2.48}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 67}, 'wind': {'speed': 7.12, 'deg': 333, 'gust': 15.3}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-03 03:00:00'}, {'dt': 1677823200, 'main': {'temp': 276.36, 'feels_like': 272.69, 'temp_min': 276.36, 'temp_max': 276.36, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 1013, 'humidity': 61, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 100}, 'wind': {'speed': 4.19, 'deg': 316, 'gust': 8.04}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-03 06:00:00'}, {'dt': 1677834000, 'main': {'temp': 275.18, 'feels_like': 272.28, 'temp_min': 275.18, 'temp_max': 275.18, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 1015, 'humidity': 67, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'clouds': {'all': 47}, 'wind': {'speed': 2.77, 'deg': 318, 'gust': 4.4}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2023-03-03 09:00:00'}, {'dt': 1677844800, 'main': {'temp': 274.72, 'feels_like': 272.15, 'temp_min': 274.72, 'temp_max': 274.72, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 1017, 'humidity': 70, 'temp_kf': 0}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'clouds': {'all': 42}, 'wind': {'speed': 2.34, 'deg': 348, 'gust': 3.35}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-03-03 12:00:00'}, {'dt': 1677855600, 'main': {'temp': 277.45, 'feels_like': 276.15, 'temp_min': 277.45, 'temp_max': 277.45, 'pressure': 1018, 'sea_level': 1018, 'grnd_level': 1017, 'humidity': 54, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 1.61, 'deg': 70, 'gust': 2.43}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-03-03 15:00:00'}, {'dt': 1677866400, 'main': {'temp': 279.77, 'feels_like': 278.04, 'temp_min': 279.77, 'temp_max': 279.77, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 1016, 'humidity': 41, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 2.41, 'deg': 99, 'gust': 3.18}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2023-03-03 18:00:00'}, {'dt': 1677877200, 'main': {'temp': 278.82, 'feels_like': 275.1, 'temp_min': 278.82, 'temp_max': 278.82, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 1015, 'humidity': 50, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 5.51, 'deg': 134, 'gust': 6.54}, 'visibility': 10000, 'pop': 0.31, 'sys': {'pod': 'd'}, 'dt_txt': '2023-03-03 21:00:00'}, {'dt': 1677888000, 'main': {'temp': 276.15, 'feels_like': 271, 'temp_min': 276.15, 'temp_max': 276.15, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 1012, 'humidity': 84, 'temp_kf': 0}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}, {'id': 613, 'main': 'Snow', 'description': 'shower sleet', 'icon': '13n'}], 'clouds': {' ...

# %%
def get_weather_data(data):
    """ Die Funktion wird dazu verwendet , die verschiedene Wetter-Datenpunkte 
    einer gegebenen Stadt auszulesen 
        
    Args:
        data (dict): Dictionnary of weather params for the last 5 days 
    """
    # in list is weather , wind , dt_txt ,main
    #in main(dict) is temp_max , temp_min , feels_like , temp , pressure and humidity
    #in Wind(dict) is speed
    # in weather (list(dict)) is main , description and Icon 
    
for i in response :
    pass
